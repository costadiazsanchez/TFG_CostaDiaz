# %%
import numpy as np
import pandas as pd

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Sampling of 90% of 2021VAERSDATA

vdata = pd.read_csv("2021VAERSDATA.csv", encoding="iso-8859-1")
vdata.sample(frac=0.9).to_csv("vdata_sample.csv", index=False)

# %%
# Sampling of 90% of 2021VAERSVAX

vax = pd.read_csv("2021VAERSVAX.csv", encoding="iso-8859-1")
vax.sample(frac=0.9).to_csv("vax_sample.csv", index=False)

# %%
vdata = pd.read_csv("vdata_sample.csv") # No encoding
vax = pd.read_csv("vax_sample.csv")

vdata_with_vax = vdata.join(vax.set_index("VAERS_ID"),on="VAERS_ID",how="inner")

len(vdata), len(vax), len(vdata_with_vax)

## Result suggests that some individual and vaccine data was not captured.
# Out:
# (668049, 707557, 636851)

# %%
# Data that was not captured

lost_vdata = vdata.loc[~vdata.index.isin(vdata_with_vax.index)]
lost_vdata
# Out:
#         VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 9        1121149  03/21/2021    NY     42.0     42.0      NaN   F      NaN
# 11       1141789  03/28/2021    IL     61.0     61.0      NaN   F      NaN
# 16       1278567  05/01/2021    TX     33.0     33.0      NaN   F      NaN
# 18       1228129  04/19/2021    KY      NaN      NaN      NaN   M      NaN
# 20       1463338  07/11/2021    CA     44.0      NaN      NaN   F      NaN
# ...          ...         ...   ...      ...      ...      ...  ..      ...
# 667963   1193645  04/11/2021    IN     55.0     55.0      NaN   F      NaN
# 667978   1354415  05/27/2021    CA     18.0     18.0      NaN   M      NaN
# 668011   1959173  12/17/2021    ME     12.0     12.0      NaN   M      NaN
# 668032   1366783  06/02/2021    MI     77.0      NaN      NaN   M      NaN
# 668045    917362  01/02/2021    TX     65.0     65.0      NaN   F      NaN
#
#                                              SYMPTOM_TEXT DIED  ...  \
# 9       24 hours after receiving the second vaccine, I...  NaN  ...
# 11       lightheaded, dizzy,feeling nervous 160/90,82, 16  NaN  ...
# 16      Extreme pain in arm,  unable to lift higher th...  NaN  ...
# 18      LETHARGIC; CHILLS; FEVER; BONE ACHINESS; This ...  NaN  ...
# 20      Fainting Feeling; Feeling.difficulty catching ...  NaN  ...
# ...                                                   ...  ...  ...
# 667963  24 hours after injection, experienced fever (1...  NaN  ...
# 667978  Sickle cell disease patient with a history of ...  NaN  ...
# 668011   12yo child received 5-11yo vaccine dose in error  NaN  ...
# 668032  MASSIVE BLUNT FORCE TRAUMA; CAR ACCIDENT; BLEE...    Y  ...
# 668045  Low grade fever 24 hours after immunization, a...  NaN  ...
#
#                                                CUR_ILL  \
# 9                                                  NaN
# 11                                                none
# 16                                                None
# 18                                                 NaN
# 20                                                 NaN
# ...                                                ...
# 667963                                             NaN
# 667978  Vaso-occlusive crisis from sickle cell disease
# 668011                                         unknown
# 668032         Artificial cardiac pacemaker user; COPD
# 668045                                             NaN
#
#                                                   HISTORY PRIOR_VAX  \
# 9                                            Constipation       NaN
# 11                                                   none       NaN
# 16                                                   None       NaN
# 18            Comments: The patent had no known allergies       NaN
# 20      Comments: List of non-encoded Patient Relevant...       NaN
# ...                                                   ...       ...
# 667963                                 M.S,  asthma, COPD       NaN
# 667978                                sickle cell disease       NaN
# 668011                                            unknown       NaN
# 668032  Comments: The patient was on unspecified respi...       NaN
# 668045                                                NaN       NaN
#
#                       SPLTTYPE  FORM_VERS TODAYS_DATE BIRTH_DEFECT OFC_VISIT  \
# 9                          NaN          2  03/21/2021          NaN         Y
# 11                         NaN          2  03/28/2021          NaN       NaN
# 16                         NaN          2  05/01/2021          NaN       NaN
# 18         USJNJFOC20210321601          2  03/15/2021          NaN       NaN
# 20      USPFIZER INC2021821230          2  07/05/2021          NaN       NaN
# ...                        ...        ...         ...          ...       ...
# 667963                     NaN          2  04/11/2021          NaN       NaN
# 667978                     NaN          2  05/27/2021          NaN       NaN
# 668011                     NaN          2  12/17/2021          NaN       NaN
# 668032     USJNJFOC20210554454          2  06/01/2021          NaN       NaN
# 668045                     NaN          2  01/02/2021          NaN       NaN
#
#        ER_ED_VISIT                              ALLERGIES
# 9              NaN                                   NKDA
# 11             NaN                                   none
# 16             NaN                                   None
# 18             NaN                                    NaN
# 20             NaN                                    NaN
# ...            ...                                    ...
# 667963         NaN                                    NaN
# 667978         NaN  Morphine, ketamine, Zofran,  Tegaderm
# 668011         NaN                                 pollen
# 668032         NaN                                    NaN
# 668045         NaN                                    NaN
#
# [63533 rows x 35 columns]

# %%
lost_vax = vax[~vax["VAERS_ID"].isin(vdata.index)]
lost_vax
# Out:
#         VAERS_ID VAX_TYPE          VAX_MANU  VAX_LOT VAX_DOSE_SERIES  \
# 0        1615727  COVID19           MODERNA  040A21A               1
# 1         934968  COVID19   PFIZER\BIONTECH      NaN             UNK
# 2        1236682  COVID19           MODERNA  037B21A               1
# 3        1040515   VARCEL  MERCK & CO. INC.  S033540             UNK
# 4         944370  COVID19   PFIZER\BIONTECH   EL1284               2
# ...          ...      ...               ...      ...             ...
# 707552   1357071  COVID19           JANSSEN  Unknown             UNK
# 707553   1218348  COVID19   PFIZER\BIONTECH      NaN             UNK
# 707554   1273278  COVID19   PFIZER\BIONTECH      NaN               2
# 707555   1923068  COVID19   PFIZER\BIONTECH   EN6202               1
# 707556   1531727  COVID19           MODERNA   939902               1
#
#        VAX_ROUTE VAX_SITE                             VAX_NAME
# 0             OT       LA          COVID19 (COVID19 (MODERNA))
# 1            NaN      NaN  COVID19 (COVID19 (PFIZER-BIONTECH))
# 2             IM       RA          COVID19 (COVID19 (MODERNA))
# 3            NaN       RL                  VARICELLA (VARIVAX)
# 4             IM       LA  COVID19 (COVID19 (PFIZER-BIONTECH))
# ...          ...      ...                                  ...
# 707552       NaN      NaN          COVID19 (COVID19 (JANSSEN))
# 707553       NaN      NaN  COVID19 (COVID19 (PFIZER-BIONTECH))
# 707554       NaN       LA  COVID19 (COVID19 (PFIZER-BIONTECH))
# 707555       NaN       LA  COVID19 (COVID19 (PFIZER-BIONTECH))
# 707556        IM       RA          COVID19 (COVID19 (MODERNA))
#
# [707557 rows x 8 columns]

# %%
# Other way to join data by performing a left outer join.

vdata_with_vax_left = vdata.join(vax.set_index("VAERS_ID"),on="VAERS_ID")
vdata_with_vax_left.groupby("VAERS_ID").size().sort_values()

# A left outer join assures that all the rows on the left table are always represented. 
# If there are no rows on the right
# then all the right columns will be filled with None values.
# Out:
# VAERS_ID
# 910642      1
# 1573837     1
# 1573838     1
# 1573839     1
# 1573840     1
#            ..
# 1147078    11
# 1147080    11
# 1151048    11
# 962303     12
# 2523925    17
# Length: 668049, dtype: int64

# %%
len(vdata_with_vax_left), len(vdata_with_vax_left.VAERS_ID.unique())
# Out:
# (700384, 668049)

# %%
dead = vdata[vdata.DIED == "Y"]
vax19 = vax[vax.VAX_TYPE == "COVID19"]
vax19_dead = vax19.join(dead.set_index("VAERS_ID"), on="VAERS_ID", how="right")

# %%
len(vax19), len(dead), len(vax19_dead)
# Out:
# (658065, 9428, 10644)

# %%
# Cheching the duplicated entries on the joined table.
len(vax19_dead[vax19_dead.VAERS_ID.duplicated()]), (len(vax19_dead) - len(dead))
# Out:
# (1216, 1216)

# %%
vax19_dead["STATE"] = vax19_dead["STATE"].str.upper()
# Next sentences ensures not having repeated indexes and empty VAERS_ID
dead_lot = vax19_dead[["VAERS_ID", "VAX_LOT", "STATE"]].set_index(["VAERS_ID", "VAX_LOT"])
dead_lot_clean = dead_lot[~dead_lot.index.duplicated()]
dead_lot_clean = dead_lot_clean.reset_index()
dead_lot_clean[dead_lot_clean.VAERS_ID.isna()]

baddies = dead_lot_clean.groupby("VAX_LOT").size().sort_values(ascending=False)
for i, (lot, cnt) in enumerate(baddies.items()):
    print(lot, cnt, len(dead_lot_clean[dead_lot_clean.VAX_LOT == lot].groupby("STATE")))
    if i == 10:
        break
# Out:
# Unknown 236 32
# EN6201 124 28
# EN6200 95 21
# EN5318 92 26
# EN6198 90 22
# EL9261 87 19
# unknown 84 20
# EL9269 84 16
# EL3248 79 16
# EN6202 78 18
# EM9810 75 17
